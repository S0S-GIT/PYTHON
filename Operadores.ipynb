# %% [markdown]
# <a href="https://colab.research.google.com/github/SOS-escritos/PYTHON/blob/main/Operadores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x= 5
y= 11

# %%
x>11 and y<5
# Out:
# False

# %%
x<11 and y>5
# Out:
# True

# %%
x<11 and y<5
# Out:
# False

# %%
x<11 or y<5
# Out:
# True

# %%
x>11 and y>5
# Out:
# False

# %%
not (x<y)
# Out:
# False

# %%
not (x>y)
# Out:
# True

# %%
Lista=["a","b","d","e","f"]

# %%
"a" in Lista
# Out:
# True

# %%
"c" in Lista
# Out:
# False
