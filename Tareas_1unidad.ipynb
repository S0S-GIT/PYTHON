# %% [markdown]
# <a href="https://colab.research.google.com/github/S0S-GIT/PYTHON/blob/main/Tareas_1unidad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Adjunta la captura del código en python de las siguientes actividades:
#
# 1. Generación de Qr con nombre del estudiante
# 2. Programa que describe las materias que le gustan y no le gustan al estudiante
# 3. Actividad de mayor que, menor que, mayor o igual que, menor o igual que y o igual que
# 5. Conversor de grados Celsius a Farenheit
# 6. Programa que solicita información del estudiante

# %% [markdown]
# Act.3 Actividad de mayor que, menor que, mayor o igual que, menor o igual que y o igual que:
# 1. Te pida ingresar
# 2. numeros: a y b realice las operaciones (+, -, *, /) indique si es True o False para: "==", !=, >=, <=, >, <

# %%
a = int(input("Ingresa el primer número: "))
b = int(input("Ingresa el segundo número: "))

print("Suma:", a + b)
print("Resta:", a - b)
print("Multiplicación:", a * b)
print("División:", a / b)
print("a == b:", a == b)
print("a != b:", a != b)
print("a >= b:", a >= b)
print("a <= b:", a <= b)
print("a < b:", a < b)
print("a > b:", a > b)
# Out:
# Ingresa el primer número: 45
# Ingresa el segundo número: 54
# Suma: 99
# Resta: -9
# Multiplicación: 2430
# División: 0.8333333333333334
# a == b: False
# a != b: True
# a >= b: False
# a <= b: True
# a < b: True
# a > b: False

# %% [markdown]
# Act.5 Programa que solicita información del estudiante:
#
# 1. Pida el nombre del estudiante
# 2. Pida el año de nacimiento
# 3. Pida el mes de nacimiento
# 4. Pida el año actual
# 5. Pida el mes actual
# 6. Te imprima tu edad + el número de mes y el nombre

# %%
# !pip install datetime
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.6/270.6 kB 20.0 MB/s eta 0:00:00
# ...

# %%
from datetime import datetime
nombre =(input("Cual es tu nombre/s: "))
apellido_P =(input("Cual es tu apellido parterno: "))
apellido_M =(input("Cual es tu apellido materno: "))
def nom_com(nombre, apellido_P, apellido_M):
    print("Hola " + nombre.title() + " " + apellido_P.title() + " " + apellido_M.title())
Mes_NA =int(input("Cual es tu mes de nacimiento en numero= "))
Año_NA =int(input("Cual es tu año de nacimiento= "))

Fe_AC= datetime.now()
Año_AC= Fe_AC.year
Mes_AC= Fe_AC.month

if Mes_NA <= Mes_AC:
    edad = Año_AC - Año_NA
    mes = Mes_AC - Mes_NA
else:
    edad = Año_AC - Año_NA - 1
    mes = (12 - Mes_NA) + Mes_AC

m_a = (edad * 12) + mes

def años_e(edad, mes, m_a):
    print("Tú tienes " + str(edad) + " años con " + str(mes) + " meses y " + str(m_a) + " meses vividos.")

nom_com(nombre, apellido_P, apellido_M)
años_e(edad, mes, m_a)
# Out:
# Cual es tu nombre/s: Oscar De Jesus
# Cual es tu apellido parterno: Delgado
# Cual es tu apellido materno: Alonso
# Cual es tu mes de nacimiento en numero= 09
# Cual es tu año de nacimiento= 2007
# Hola Oscar De Jesus Delgado Alonso
# Tú tienes 19 años con 0 meses y 228 meses vividos.

# %% [markdown]
# Ejercicio: Elabora un script el cual tenga
#
# 1. Una función llamada com_f(num1,num2) y reciba parametros de entrada.
# 2. Debe imprimir la relación entre los dos numeros:Menor que, Mayor que o igual que.
# 3. La función no retorna ningun valor. Resultado esperado: El número X es menor que Y

# %%
def con_f(num1, num2):
  if num1 < num2:
    print(f"El número {num1} es menor que {num2}")
  elif num1>num2:
    print(f"El número {num2} es menor que {num1}")
  else:
    print(f"El número {num1} es igual {num2}")

# %%
num1 =int(input("Ingresa un numero entero: "))
num2 =int(input("Ingresa el segundo numero entero: "))
con_f(num1,num2)
# Out:
# Ingresa un numero entero: 4
# Ingresa el segundo numero entero: 5
# El número 4 es menor que 5
