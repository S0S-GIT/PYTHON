# %% [markdown]
# <a href="https://colab.research.google.com/github/S0S-GIT/PYTHON/blob/main/definir_variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def saludo():
  print("Hola mundo!")
saludo()
# Out:
# Hola mundo!

# %%
def grados_Celcius (C):
  f=(9/5)*C+32
  print(f"La temperatura en Farenhert es:{f}")
grados_Celcius(26)
# Out:
# La temperatura en Farenhert es:78.80000000000001

# %%
def grados_Celcius (C):
  f=(9/5)*C+32
  print("La temperatura en Farenhert es{: .2f} y en celcius es{: .2f}" .format(f, C))
grados_Celcius(26)
# Out:
# La temperatura en Farenhert es 78.80 y en celcius es 26.00

# %%
def nombre_completo(nombre, apellido_P, apellido_M):
  print(nombre.title() + " " + apellido_P.title() + " " + apellido_M.title())
nombre_completo("Oscar de Jesus", "Delgado", "Alonso")
# Out:
# Oscar De Jesus Delgado Alonso

# %%
def cal_cuadrado(num):
  cuadrado = num ** 2
  print("El cuadrado de 10 es:", cuadrado)
cal_cuadrado(10)
# Out:
# El cuadrado de 10 es: 100

# %%
def cal_cuadrado(num):
  cuadrado = num ** 2
  return cuadrado
num=int(input("Escribe un numero entero: "))
res=cal_cuadrado(num)
print(f"El cuadrado de {num} es: {res}")
# Out:
# Escribe un numero entero: 4
# El cuadrado de 4 es: 16

# %% [markdown]
# Crear una función en donde:
#
#
# 1. Pida el nombre del estudiante
# 2. Pida el año de nacimiento
# 3. Pida el mes de nacimiento
# 4. Pida el año actual
# 5. Pida el mes actual
# 6. Te imprima tu edad + el número de mes y el nombre

# %%
# !pip install datetime
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.6/270.6 kB 9.3 MB/s eta 0:00:00
# ...

# %%
from datetime import datetime
nombre =(input("Cual es tu nombre/s: "))
apellido_P =(input("Cual es tu apellido parterno: "))
apellido_M =(input("Cual es tu apellido materno: "))
def nom_com(nombre, apellido_P, apellido_M):
    print("Hola " + nombre.title() + " " + apellido_P.title() + " " + apellido_M.title())
Mes_NA =int(input("Cual es tu mes de nacimiento en numero= "))
Año_NA =int(input("Cual es tu año de nacimiento= "))

Fe_AC= datetime.now()
Año_AC= Fe_AC.year
Mes_AC= Fe_AC.month

if Mes_NA <= Mes_AC:
    edad = Año_AC - Año_NA
    mes = Mes_AC - Mes_NA
else:
    edad = Año_AC - Año_NA - 1
    mes = (12 - Mes_NA) + Mes_AC

m_a = (edad * 12) + mes

def años_e(edad, mes, m_a):
    print("Tú tienes " + str(edad) + " años con " + str(mes) + " meses y " + str(m_a) + " meses vividos.")

nom_com(nombre, apellido_P, apellido_M)
años_e(edad, mes, m_a)
# Out:
# Cual es tu nombre/s: Oscar de Jesus
# Cual es tu apellido parterno: Delgado
# Cual es tu apellido materno: Alonso
# Cual es tu mes de nacimiento en numero= 09
# Cual es tu año de nacimiento= 2007
# Hola Oscar De Jesus Delgado  Alonso
# Tú tienes 19 años con 0 meses y 228 meses vividos.
